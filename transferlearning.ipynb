# %% [markdown]
# <a href="https://colab.research.google.com/github/codiezodie/Image-Recognition/blob/main/transferlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Aug 25 12:19:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.19.0'

# %%
from keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

# %%
model = VGG16(weights='imagenet', include_top=True,input_shape=(224,224,3))

# %%
img_path = '/content/perfume.jpg'
img = image.load_img(img_path, target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
# Use the model to predict the class
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
preds
# Out:
# array([[2.52954636e-11, 5.85059823e-09, 6.73264721e-13, 1.59251166e-13,
#         3.98944875e-13, 1.76978798e-12, 4.53279688e-12, 5.28832478e-10,
#         7.94963678e-11, 6.80775315e-12, 1.41080647e-09, 1.06440927e-08,
#         3.27647631e-10, 1.25563698e-10, 2.73557815e-10, 2.00476635e-09,
#         5.22237187e-09, 6.03079739e-11, 6.73442621e-11, 7.72399311e-10,
#         4.52404919e-11, 3.86849363e-12, 9.07795193e-12, 3.39269389e-12,
#         1.16114531e-11, 2.14760900e-11, 2.88507170e-11, 8.10214743e-11,
#         7.37210640e-12, 5.97139505e-10, 2.04269313e-09, 1.60034555e-10,
#         5.92201913e-11, 5.88025809e-12, 3.01852011e-12, 2.88632659e-11,
#         1.79746551e-09, 3.60895133e-11, 4.15714858e-12, 3.64299806e-11,
#         1.64471506e-10, 2.89339282e-11, 1.13210552e-11, 1.69984166e-11,
#         1.93905239e-11, 9.42874945e-11, 7.12019665e-10, 9.08912789e-12,
#         1.74566403e-11, 9.64012290e-12, 4.38382794e-12, 3.43904104e-13,
# ...

# %%
# Get the top 10 predictions with class names
decode_preds = decode_predictions(preds, top=10)[0]

# %%
for pred in decode_preds:
  print(pred[1], ":", pred[2])
# Out:
# perfume : 0.997345
# saltshaker : 0.0006543034
# cocktail_shaker : 0.0004778575
# lighter : 0.00042437005
# beer_glass : 0.00041622669
# wine_bottle : 0.00017941647
# eggnog : 8.33281e-05
# lotion : 7.336748e-05
# soap_dispenser : 6.7281304e-05
# vase : 4.7739177e-05
