# %% [markdown]
# <a href="https://colab.research.google.com/github/codiezodie/AdvJava/blob/main/Yolo11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Perform object detection on an image
results = model("/content/sample_data/DOG.jpg")
results[0].show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3134340085.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # Load a model
#       4 model = YOLO("yolo11n.pt")
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-seg.pt")

# Perform object detection on an image
results = model("/content/sample_data/yolo.jpg")
results[0].show()
# Out:
# ...
#
# image 1/1 /content/sample_data/yolo.jpg: 480x640 1 bicycle, 1 car, 1 truck, 1 dog, 17.3ms
# Speed: 2.5ms preprocess, 17.3ms inference, 40.9ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=515x386>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-pose.pt")

# Perform object detection on an image
results = model("/content/sample_data/yolo.jpg", save=True)
results[0].show()
# Out:
# ...
#
# image 1/1 /content/sample_data/yolo.jpg: 480x640 (no detections), 30.7ms
# Speed: 3.5ms preprocess, 30.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/pose/predict
# <PIL.Image.Image image mode=RGB size=515x386>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")

# Perform object detection on an image
results = model("/content/sample_data/cat.jpg", save=True)
results[0].show()
# Out:
# ...
#
# ...
# image 1/1 /content/sample_data/cat.jpg: 224x224 tiger_cat 0.55, tabby 0.17, Egyptian_cat 0.06, red_fox 0.04, dhole 0.03, 4.1ms
# Speed: 15.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
# !wget https://media.w3.org/2010/05/sintel/trailer_hd.mp4 -O sample.mp4
# Out:
# --2025-11-09 15:35:50--  https://media.w3.org/2010/05/sintel/trailer_hd.mp4
# Resolving media.w3.org (media.w3.org)... 104.18.23.19, 104.18.22.19, 2606:4700::6812:1613, ...
# Connecting to media.w3.org (media.w3.org)|104.18.23.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14621544 (14M) [video/mp4]
# Saving to: ‘sample.mp4’
#
# sample.mp4          100%[===================>]  13.94M  --.-KB/s    in 0.1s
#
# 2025-11-09 15:35:50 (133 MB/s) - ‘sample.mp4’ saved [14621544/14621544]

# %%
from ultralytics import YOLO
model = YOLO("yolo11l.pt")
results = model("sample.mp4", save=True)
print("Results saved at:", results[0].save_dir)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1253) /content/sample.mp4: 384x640 (no detections), 53.6ms
# video 1/1 (frame 2/1253) /content/sample.mp4: 384x640 (no detections), 31.2ms
# video 1/1 (frame 3/1253) /content/sample.mp4: 384x640 (no detections), 31.2ms
# video 1/1 (frame 4/1253) /content/sample.mp4: 384x640 (no detections), 25.3ms
# video 1/1 (frame 5/1253) /content/sample.mp4: 384x640 (no detections), 25.3ms
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open('/content/sample.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'<video width=640 controls><source src="{data_url}" type="video/mp4"></video>')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3153625628.py in <cell line: 0>()
#       2 from base64 import b64encode
#       3
# ----> 4 mp4 = open('/content/runs/detect/predict','rb').read()
#       5 data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
#       6 HTML(f'<video width=640 controls><source src="{data_url}" type="video/mp4"></video>')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/predict'
